# %%
from pandas import *
from os import listdir, getcwd
from os.path import join
from json import loads
from nltk import *
from nltk import download
from datetime import date, datetime
import pickle
download('stopwords')
download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tim\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tim\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
transcript_dir = 'resources/hackathon_data/company_transcripts/'
price_dir = 'resources/hackathon_data/company_prices_returns/'
WORD_THRESHOLD = 20

# %%
transcript_files = listdir(transcript_dir)
price_files = listdir(price_dir)

# %%
def cut_word_threshold(lst, threshold):
    return [x for x in lst if len(x.split()) >= threshold]

# %%
df_all = DataFrame(columns=['ticker', 'datetime', 'date', 'year', 'quarter', 'close', 'returns', 'next_returns', 'usable_returns', 'body', 'earnings_word_count'])

# %%
# Load all data
for index in range(len(transcript_files)):
    trans_file = transcript_files[index]
    price_file = price_files[index]
    
    # Get ticker
    ticker = trans_file.split('.')[0]

    # Grab data
    df_trans_raw = read_json(transcript_dir + trans_file)[['date', 'body']]
    df_price_raw = read_csv(price_dir + price_file)
    
    if len(df_trans_raw) == 0 or len(df_price_raw) == 0:
        continue
    
    df_trans = df_trans_raw
    df_price = df_price_raw
    # Rename Columns
    df_trans.columns = ['datetime', 'body']
    df_price.columns = ['date', 'close', 'returns']

    # Convert to datetime.date
    df_trans['date'] = df_trans['datetime'].apply(lambda x: x.date())
    # Convert to datetime.date
    df_price['date'] = df_price['date'].apply(lambda x: date(*[int(y) for y in x.split('-')]))
    # Shift returns from next day to current
    df_price['next_returns'] = df_price['returns'].shift(-1)
    
    # Merge pricing with earnings data
    df_merged = df_trans.merge(df_price, left_on=['date'], right_on=['date'], how='left')

    # Get returns we want to use
    df_merged['usable_returns'] = df_merged.apply(lambda x: x['next_returns'] if x['datetime'].hour >= 16 else x['returns'], axis=1)
    
    df_merged['ticker'] = ticker
    
    df_merged['year'] = df_merged['date'].apply(lambda x: x.year)
    df_merged['quarter'] = df_merged['date'].apply(lambda x: 1 if x.month <= 3 else 2 if x.month <= 6 else 3 if x.month <= 9 else 4)
    
    df_merged['body'] = df_merged['body'].apply(lambda lst: ' '.join(cut_word_threshold(lst, WORD_THRESHOLD)))
    
    df_merged['earnings_word_count'] = df_merged['body'].apply(lambda x: len(x.split()))
    
    df_all = df_all.append(df_merged, sort=False)

# %%
df_all[['ticker', 'datetime', 'date', 'year', 'quarter', 'close', 'returns', 'next_returns', 'usable_returns', 'body']]
# Out:
#    ticker            datetime        date  year quarter       close   returns  \
# 0       A 2012-02-15 16:30:00  2012-02-15  2012       1    8.890000 -0.012222
# 1       A 2012-08-15 16:30:00  2012-08-15  2012       3   10.150000  0.002964
# 2       A 2012-11-19 16:30:00  2012-11-19  2012       4   12.070000  0.026360
# 3       A 2013-02-14 16:30:00  2013-02-14  2013       1   13.990000 -0.045703
# 4       A 2013-05-14 16:30:00  2013-05-14  2013       2   18.100000  0.021445
# 5       A 2013-08-14 16:30:00  2013-08-14  2013       3   16.170000 -0.011614
# 6       A 2015-11-17 16:30:00  2015-11-17  2015       4   42.299999 -0.012375
# 7       A 2016-02-16 16:30:00  2016-02-16  2016       1   38.610001  0.020888
# 8       A 2016-05-16 16:30:00  2016-05-16  2016       2   32.119999  0.019359
# 9     ZTS 2014-11-04 08:30:00  2014-11-04  2014       4   39.119999  0.037116
# 10    ZTS 2015-02-11 08:30:00  2015-02-11  2015       1   45.770000  0.042359
# 11    ZTS 2015-05-05 08:30:00  2015-05-05  2015       2   45.680000  0.006167
# 12    ZTS 2013-04-30 10:00:00  2013-04-30  2013       2   33.020000  0.011023
# 13    ZTS 2013-08-06 08:30:00  2013-08-06  2013       3   31.129999 -0.003840
# 14    ZTS 2013-11-05 08:30:00  2013-11-05  2013       4   31.690001 -0.007516
# 15    ZTS 2015-11-03 08:30:00  2015-11-03  2015       4   46.630001  0.054023
# 16    ZTS 2016-02-16 08:30:00  2016-02-16  2016       1   40.430000  0.000000
# 17    ZTS 2016-05-04 08:30:00  2016-05-04  2016       2   47.049999 -0.022845
# 18    ZTS 2016-08-03 08:30:00  2016-08-03  2016       3   51.209999  0.029968
# 19    ZTS 2016-11-02 08:30:00  2016-11-02  2016       4   50.110001  0.060529
# 20    ZTS 2017-02-16 08:30:00  2017-02-16  2017       1   52.779999 -0.042974
# 21    ZTS 2019-08-06 08:30:00  2019-08-06  2019       3  121.169998  0.076397
# 22    ZTS 2019-11-07 08:30:00  2019-11-07  2019       4  121.029999 -0.003622
# 23    ZTS 2020-02-13 08:30:00  2020-02-13  2020       1         NaN       NaN
#
#     next_returns  usable_returns  \
# 0       0.023622        0.023622
# 1      -0.023645       -0.023645
# 2       0.034797        0.034797
# 3       0.036455        0.036455
# 4       0.039226        0.039226
# 5      -0.027829       -0.027829
# 6      -0.013002       -0.013002
# 7       0.018907        0.018907
# 8       0.016189        0.016189
# 9       0.001913        0.001913
# 10     -0.006926       -0.006926
# 11      0.009738        0.009738
# 12     -0.049163       -0.049163
# 13      0.020130        0.020130
# 14      0.011749        0.011749
# 15      0.017193        0.017193
# 16      0.019231        0.019231
# 17     -0.006421       -0.006421
# 18     -0.002282       -0.002282
# 19     -0.005566       -0.005566
# 20     -0.026437       -0.026437
# 21     -0.003442       -0.003442
# 22     -0.007281       -0.007281
# 23     -0.100104       -0.100104
# 24      0.027078        0.027078
# 25     -0.021088       -0.021088
# 26     -0.009603       -0.009603
# 27     -0.016735       -0.016735
# 28     -0.017699       -0.017699
# 0       0.006596       -0.001646
# ..           ...             ...
# 23      0.001870        0.001870
# 24      0.016917        0.016917
# 25      0.017041        0.017041
# 26      0.022844        0.022844
# 27      0.000185        0.000185
# 28     -0.013971       -0.013971
# 0       0.020502        0.043404
# 1       0.006007       -0.041966
# 2       0.002187        0.062892
# 3      -0.015703        0.045480
# 4       0.022625        0.056771
# 5       0.005817        0.013361
# 6       0.029866       -0.064547
# 7      -0.007769        0.011792
# 8       0.002794       -0.030987
# 9       0.003834        0.037116
# 10      0.000437        0.042359
# 11     -0.008538        0.006167
# 12      0.011205        0.011023
# 13      0.003534       -0.003840
# 14     -0.013253       -0.007516
# 15     -0.001716        0.054023
# 16      0.033886        0.000000
# 17      0.025292       -0.022845
# 18      0.003906        0.029968
# 19     -0.023149        0.060529
# 20     -0.005116       -0.042974
# 21     -0.002311        0.076397
# 22     -0.026192       -0.003622
# 23           NaN             NaN
#
#                                                  body
# 0   Good day, ladies and gentlemen, and welcome to...
# 1   Good day, ladies and gentlemen, and welcome to...
# 2   Good day, ladies and gentlemen, and welcome to...
# 3   Good day, ladies and gentlemen, and welcome to...
# 4   Good day, ladies and gentlemen, and welcome to...
# 5   Good day, ladies and gentlemen, and welcome to...
# 6   At this time all participants are in a listen-...
# 7   Good day, ladies and gentlemen, and welcome to...
# 8   Good day, ladies and gentlemen, and welcome to...
# 9   Good day, ladies and gentlemen, and welcome to...
# 10  Good day, ladies and gentlemen, and welcome to...
# 11  Good day, ladies and gentlemen, and welcome to...
# 12  Good day, ladies and gentlemen, and welcome to...
# 13  Good day, ladies and gentlemen, and welcome to...
# 14  Good day, ladies and gentlemen, and welcome to...
# 15  Good day, ladies and gentlemen, and welcome to...
# 16  Good day, ladies and gentlemen, and welcome to...
# 17  Good day, ladies and gentlemen, and welcome to...
# 18  Good day, ladies and gentlemen, and welcome to...
# 19  Good day, ladies and gentlemen. And welcome to...
# 20  Good afternoon, and welcome to the Agilent Tec...
# 21  Good afternoon, and welcome to the Agilent Tec...
# 22  Good day, ladies and gentlemen. And welcome to...
# 23  Good day, ladies and gentlemen, and welcome to...
# 24  Good day, ladies and gentlemen. And welcome to...
# 25  Good day, ladies and gentlemen. And welcome to...
# 26  Ronald S. Nersesian - Executive Vice President...
# 27  Good day, ladies and gentlemen and welcome to ...
# 28  At this time, I would like to welcome everyone...
# 0   Good day, and welcome to the American Airlines...
# ..                                                ...
# 23  Good day, ladies and gentlemen, and welcome to...
# 24  Good day, ladies and gentlemen, and thank you ...
# 25  Good day, ladies and gentlemen, and thank you ...
# 26  Good day, ladies and gentlemen and thank you f...
# 27  Good day, ladies and gentlemen. And thank you ...
# 28  Good day, ladies and gentlemen, and welcome to...
# 0   Welcome to the Third Quarter 2017 Financial Re...
# 1   Good day, and welcome to the First Quarter 201...
# 2   Good day, and welcome to the second quarter of...
# 3   Good day, and welcome to the Third Quarter 201...
# 4   Welcome to the Fourth Quarter and Full-year 20...
# 5   Welcome to the First Quarter 2019 Financial Re...
# 6   Welcome to the Fourth Quarter 2013 Financial R...
# 7   Welcome to the First Quarter 2014 Financial Re...
# 8   Welcome to the Second Quarter 2014 Financial R...
# 9   Welcome to the Third Quarter 2014 Financial Re...
# 10  Welcome to the Fourth Quarter 2014 Financial R...
# 11  Welcome to the first quarter 2015 financial re...
# 12  Welcome to the Zoetis First Quarter 2013 Finan...
# 13  Welcome to the Second Quarter 2013 Financial R...
# 14  Welcome to the Third Quarter 2013 Financial Re...
# 15  Good day and welcome to the Third Quarter 2015...
# 16  Good day and welcome to the fourth quarter and...
# 17  Good day and welcome to the First Quarter 2016...
# 18  Good day, and welcome to the Second Quarter 20...
# 19  Good day, and welcome to the Third Quarter 201...
# 20  Welcome to the fourth quarter and full year 20...
# 21  Welcome to the Second Quarter 2019 Financial R...
# 22  Welcome to the Third Quarter 2019 Financial Re...
# 23  Good day. And welcome to the Fourth Quarter an...
#
# [12379 rows x 10 columns]

# %%
df_all.to_csv('all_merged_data.csv')
